# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_stroke=pd.read_csv('ml_datasets/healthcare-dataset-stroke-data.csv')

df_stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# sns.pairplot(df_stroke)

# %% [markdown]
#     PREPROCESSING THE DATA

# %%
df_stroke.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df_stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
print(
    df_stroke.gender.value_counts
)
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Male
# 1       Female
# 2         Male
# 3       Female
# 4       Female
#          ...
# 5105    Female
# 5106    Female
# 5107    Female
# 5108      Male
# 5109    Female
# Name: gender, Length: 5110, dtype: object>

# %%
female_bmi_avg=df_stroke[df_stroke['gender'] == 'Female']['bmi'].mean()
male_bmi_avg=df_stroke[df_stroke['gender']== 'Male']['bmi'].mean()

print(female_bmi_avg,male_bmi_avg)
# Out:
# 29.065757680358992 28.64793635007459

# %%
df_stroke.loc[df_stroke['gender'] == 'Female', 'bmi'] = df_stroke.loc[df_stroke['gender'] == 'Female', 'bmi'].fillna(female_bmi_avg)

df_stroke.loc[df_stroke['gender'] == 'Male', 'bmi'] = df_stroke.loc[df_stroke['gender'] == 'Male', 'bmi'].fillna(male_bmi_avg)

# %%
df_stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
df_stroke.gender=df_stroke.gender.replace({
    'Male':1,
    'Female':0
})
df_stroke.ever_married=df_stroke.ever_married.replace({
    'Yes':1,
    'No':0
})

df_stroke
# Out:
#          id gender   age  hypertension  heart_disease  ever_married  \
# 0      9046      1  67.0             0              1             1
# 1     51676      0  61.0             0              0             1
# 2     31112      1  80.0             0              1             1
# 3     60182      0  49.0             0              0             1
# 4      1665      0  79.0             1              0             1
# ...     ...    ...   ...           ...            ...           ...
# 5105  18234      0  80.0             1              0             1
# 5106  44873      0  81.0             0              0             1
# 5107  19723      0  35.0             0              0             1
# 5108  37544      1  51.0             0              0             1
# 5109  44679      0  44.0             0              0             1
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
df_stroke.smoking_status.unique
# Out:
# <bound method Series.unique of 0       formerly smoked
# 1          never smoked
# 2          never smoked
# 3                smokes
# 4          never smoked
#              ...
# 5105       never smoked
# 5106       never smoked
# 5107       never smoked
# 5108    formerly smoked
# 5109            Unknown
# Name: smoking_status, Length: 5110, dtype: object>

# %%
df_stroke = df_stroke[df_stroke['smoking_status'] != 'Unknown']

# %%
print(df_stroke.smoking_status.value_counts())
# Out:
# never smoked       1892
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
df_stroke.smoking_status=df_stroke.smoking_status.replace({
    'never smoked': 0,
    'formerly smoked':1,
    'smokes': 2
})
# Out:
# c:\Users\vikas\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_stroke
# Out:
#          id gender   age  hypertension  heart_disease  ever_married  \
# 0      9046      1  67.0             0              1             1
# 1     51676      0  61.0             0              0             1
# 2     31112      1  80.0             0              1             1
# 3     60182      0  49.0             0              0             1
# 4      1665      0  79.0             1              0             1
# ...     ...    ...   ...           ...            ...           ...
# 5102  45010      0  57.0             0              0             1
# 5105  18234      0  80.0             1              0             1
# 5106  44873      0  81.0             0              0             1
# 5107  19723      0  35.0             0              0             1
# 5108  37544      1  51.0             0              0             1
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
df_stroke.Residence_type.value_counts()
# Out:
# Urban    1814
# Rural    1752
# Name: Residence_type, dtype: int64

# %%
df_stroke.Residence_type.value_counts()
# Out:
# Urban    1814
# Rural    1752
# Name: Residence_type, dtype: int64

# %%
df_stroke.Residence_type=df_stroke.Residence_type.replace({'Urban':1, 'Rural':0})
# Out:
# c:\Users\vikas\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_stroke.work_type.value_counts()
# Out:
# Private          2285
# Self-employed     663
# Govt_job          535
# children           69
# Never_worked       14
# Name: work_type, dtype: int64

# %%
df_stroke.age=df_stroke.age.round()

# %%
df_stroke = df_stroke[df_stroke['age'] != 0]

# %%
df_stroke
# Out:
#          id gender   age  hypertension  heart_disease  ever_married  \
# 0      9046      1  67.0             0              1             1
# 1     51676      0  61.0             0              0             1
# 2     31112      1  80.0             0              1             1
# 3     60182      0  49.0             0              0             1
# 4      1665      0  79.0             1              0             1
# ...     ...    ...   ...           ...            ...           ...
# 5102  45010      0  57.0             0              0             1
# 5105  18234      0  80.0             1              0             1
# 5106  44873      0  81.0             0              0             1
# 5107  19723      0  35.0             0              0             1
# 5108  37544      1  51.0             0              0             1
#
#           work_type  Residence_type  avg_glucose_level        bmi  \
# 0           Private               1             228.69  36.600000
# ...

# %%
df_stroke.work_type.value_counts()
# Out:
# Private          2285
# Self-employed     663
# Govt_job          535
# children           69
# Never_worked       14
# Name: work_type, dtype: int64

# %%
df_stroke.work_type=df_stroke.work_type.replace({
    'children': 0,
    'Never_worked':1,
    'Self-employed':2,
    'Govt_job':3,
    'Private':4
})

df_stroke = df_stroke[df_stroke['gender'] != 'Other']
df_stroke=df_stroke.drop(['id'],axis='columns')
df_stroke=df_stroke.drop(['avg_glucose_level'],axis='columns')

# %%
df_stroke
# Out:
#      gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0         1  67.0             0              1             1          4
# 1         0  61.0             0              0             1          2
# 2         1  80.0             0              1             1          4
# 3         0  49.0             0              0             1          4
# 4         0  79.0             1              0             1          2
# ...     ...   ...           ...            ...           ...        ...
# 5102      0  57.0             0              0             1          4
# 5105      0  80.0             1              0             1          4
# 5106      0  81.0             0              0             1          2
# 5107      0  35.0             0              0             1          2
# 5108      1  51.0             0              0             1          4
#
#       Residence_type        bmi  smoking_status  stroke
# ...

# %%
df_stroke.gender.value_counts()
# Out:
# 0    2158
# 1    1407
# Name: gender, dtype: int64

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(df_stroke.drop(['stroke'],axis='columns'),df_stroke.stroke,test_size=0.33)

# %%
print(len(x_train),len(x_test))
# Out:
# 2388 1177

# %%
# model=tree.DecisionTreeClassifier()
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# c:\Users\vikas\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9524214103653356

# %%
# import pickle

# f= open("models/stroke_predict_model",'wb')
# pickle.dump(model,f)
# f.close()
